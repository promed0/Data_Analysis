# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("employee_data.csv")
df.head()
# Out:
#    ID Gender  Experience (Years)               Position  Salary
# 0   1      F                   4        DevOps Engineer  109976
# 1   2      M                   6        DevOps Engineer  120088
# 2   3      M                  17          Web Developer  181301
# 3   4      M                   7  Systems Administrator   77530
# 4   5      F                  13  Systems Administrator  152397

# %%
df.shape
# Out:
# (400, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  400 non-null    int64
#  1   Gender              400 non-null    object
#  2   Experience (Years)  400 non-null    int64
#  3   Position            400 non-null    object
#  4   Salary              400 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 15.8+ KB

# %%
df.isnull()
# Out:
#         ID  Gender  Experience (Years)  Position  Salary
# 0    False   False               False     False   False
# 1    False   False               False     False   False
# 2    False   False               False     False   False
# 3    False   False               False     False   False
# 4    False   False               False     False   False
# ..     ...     ...                 ...       ...     ...
# 395  False   False               False     False   False
# 396  False   False               False     False   False
# 397  False   False               False     False   False
# 398  False   False               False     False   False
# 399  False   False               False     False   False
#
# [400 rows x 5 columns]

# %%
df.dropna(inplace=True)

# %%
df.isnull()
# Out:
#         ID  Gender  Experience (Years)  Position  Salary
# 0    False   False               False     False   False
# 1    False   False               False     False   False
# 2    False   False               False     False   False
# 3    False   False               False     False   False
# 4    False   False               False     False   False
# ..     ...     ...                 ...       ...     ...
# 395  False   False               False     False   False
# 396  False   False               False     False   False
# 397  False   False               False     False   False
# 398  False   False               False     False   False
# 399  False   False               False     False   False
#
# [400 rows x 5 columns]

# %%
# df.loc['type'].value_counts().sum()
df['Position'].value_counts()
# Out:
# Position
# Web Developer                   43
# IT Manager                      40
# IT Security Analyst             39
# Systems Administrator           38
# Database Administrator (DBA)    38
# DevOps Engineer                 37
# Systems Analyst                 37
# Software Engineer               36
# Network Administrator           31
# IT Support Specialist           31
# Cloud Solutions Architect       30
# Name: count, dtype: int64

# %%
df.rename(columns ={'Experience (Years)':'Year'}, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Year', 'Position', 'Salary'], dtype='object')

# %%
df.describe()
# Out:
#                ID        Year        Salary
# count  400.000000  400.000000     400.00000
# mean   200.500000    9.670000  131701.19750
# std    115.614301    6.101571   43351.50899
# min      1.000000    0.000000   43643.00000
# 25%    100.750000    4.000000  100484.75000
# 50%    200.500000   10.000000  128561.50000
# 75%    300.250000   15.000000  157735.00000
# max    400.000000   20.000000  269950.00000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Year', 'Position', 'Salary'], dtype='object')

# %%
#now part of the EDA

# %%
ax = sns.countplot(x="Gender",data=df,hue='Position')#,hue="Position"
for bars in ax.containers:
    ax.bar_label(bars)

# %%
from the above chart most of the female employe are web developer and the System Analysis,, and most of the male employe are Database Administrator(DBA) 
and IT security Analysis.

# %%
ax = sns.countplot(x="Gender",data=df,hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
from chart , most of the employe are Male they are 202.

# %%
title_rating = df.groupby(['ID'], as_index=False)['Year'].sum().sort_values(by='Year', ascending=False).head(50)
# Set figure size
sns.set(rc={'figure.figsize': (20, 3)})

# Create a bar plot for top-rated movies by title and rating
sns.barplot(x='ID', y='Year', data=title_rating, hue='Year')
# plt.show()
# Out:
# <Axes: xlabel='ID', ylabel='Year'>

# %%
20 years experience employee in the company and lowest are the experience employe are below 18 years

# %%
title_rating = df.groupby(['ID'], as_index=False)['Salary'].sum().sort_values(by='Salary', ascending=False).head(50)
# Set figure size
sns.set(rc={'figure.figsize': (20, 3)})

# Create a bar plot for top-rated movies by title and rating
sns.barplot(x='ID', y='Salary', data=title_rating, hue='Salary')
# Out:
# <Axes: xlabel='ID', ylabel='Salary'>

# %%
from chart, Highest salary pick 250000 salary plus per year, are lowest salary are 20000 below.

# %%
title_rating = df.groupby(['Gender'], as_index=False)['ID'].sum().sort_values(by='ID', ascending=False)
# Set figure size
sns.set(rc={'figure.figsize': (10, 5)})

# Create a bar plot for top-rated movies by title and rating
sns.barplot(x='Gender', y='ID', data=title_rating, hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='ID'>
